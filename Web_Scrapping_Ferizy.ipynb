# %%
# !pip install google-play-scraper
# Out:
# Requirement already satisfied: google-play-scraper in /usr/local/lib/python3.10/dist-packages (1.2.4)

# %%
from google_play_scraper import app

import pandas as pd

import numpy as np

# %%
from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.nutech_integrasi.asdpmobile',
    lang='id',
    country='id',
    sort=Sort.NEWEST,
    count=1500,
    filter_score_with=None
)

# %%
df_busu = pd.DataFrame(np.array(result),columns=['review'])

df_busu = df_busu.join(pd.DataFrame(df_busu.pop('review').tolist()))

df_busu.head()
# Out:
#                                reviewId           userName  \
# 0  e3c2e2a0-4f0c-450e-a891-1b42d80e0302     Dsatia channel
# 1  5274958c-ba7b-4134-85bb-178b8693a2f7  Dimas Izha Ananta
# 2  476df1e9-f6ce-4c5f-be9b-44be54f15d16        itha firman
# 3  2d7f6757-4ee4-4c40-8045-4372d70d814c  MR Sutan Alamsyah
# 4  bd3822f1-ae60-468b-8456-e96922cc2ab4       Saya Ganteng
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/AD_cM...
# 1  https://play-lh.googleusercontent.com/a-/AD_cM...
# 2  https://play-lh.googleusercontent.com/a-/AD_cM...
# 3  https://play-lh.googleusercontent.com/a-/AD_cM...
# 4  https://play-lh.googleusercontent.com/a-/AD_cM...
#
#                                              content  score  thumbsUpCount  \
# 0  buka aplikasi loading memuat data terus gak se...      1              0
# 1      lama bet tolol loadingnya,orang mo bayar juga      1              0
# 2                            Aplikasi buluk,nyusahin      1              0
# 3                                       Sangat bagus      5              0
# 4  Minimal kalo buat database itu pake jaringan t...      2              0
#
#   reviewCreatedVersion                  at replyContent repliedAt appVersion
# 0                3.0.0 2023-08-24 08:50:48         None       NaT      3.0.0
# 1                3.0.0 2023-08-23 17:23:34         None       NaT      3.0.0
# 2                3.0.0 2023-08-23 13:28:54         None       NaT      3.0.0
# 3                3.0.0 2023-08-23 13:14:52         None       NaT      3.0.0
# 4                 None 2023-08-23 08:00:25         None       NaT       None

# %%
len(df_busu.index)
# Out:
# 1500

# %%
df_busu[['userName', 'score','at', 'content']].head()
# Out:
#             userName  score                  at  \
# 0     Dsatia channel      1 2023-08-24 08:50:48
# 1  Dimas Izha Ananta      1 2023-08-23 17:23:34
# 2        itha firman      1 2023-08-23 13:28:54
# 3  MR Sutan Alamsyah      5 2023-08-23 13:14:52
# 4       Saya Ganteng      2 2023-08-23 08:00:25
#
#                                              content
# 0  buka aplikasi loading memuat data terus gak se...
# 1      lama bet tolol loadingnya,orang mo bayar juga
# 2                            Aplikasi buluk,nyusahin
# 3                                       Sangat bagus
# 4  Minimal kalo buat database itu pake jaringan t...

# %%
new_df = df_busu[['userName', 'score','at', 'content']]
sorted_df = new_df.sort_values(by='at', ascending=False)
sorted_df.head()
# Out:
#             userName  score                  at  \
# 0     Dsatia channel      1 2023-08-24 08:50:48
# 1  Dimas Izha Ananta      1 2023-08-23 17:23:34
# 2        itha firman      1 2023-08-23 13:28:54
# 3  MR Sutan Alamsyah      5 2023-08-23 13:14:52
# 4       Saya Ganteng      2 2023-08-23 08:00:25
#
#                                              content
# 0  buka aplikasi loading memuat data terus gak se...
# 1      lama bet tolol loadingnya,orang mo bayar juga
# 2                            Aplikasi buluk,nyusahin
# 3                                       Sangat bagus
# 4  Minimal kalo buat database itu pake jaringan t...

# %%
my_df = sorted_df[['userName', 'score','at', 'content']]

# %%
my_df.head()
# Out:
#             userName  score                  at  \
# 0     Dsatia channel      1 2023-08-24 08:50:48
# 1  Dimas Izha Ananta      1 2023-08-23 17:23:34
# 2        itha firman      1 2023-08-23 13:28:54
# 3  MR Sutan Alamsyah      5 2023-08-23 13:14:52
# 4       Saya Ganteng      2 2023-08-23 08:00:25
#
#                                              content
# 0  buka aplikasi loading memuat data terus gak se...
# 1      lama bet tolol loadingnya,orang mo bayar juga
# 2                            Aplikasi buluk,nyusahin
# 3                                       Sangat bagus
# 4  Minimal kalo buat database itu pake jaringan t...

# %%
my_df.to_excel('ferizy dataset.xlsx', encoding='utf-8')
